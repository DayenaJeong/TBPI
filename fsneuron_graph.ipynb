# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.legend_handler import HandlerTuple

# %% [markdown]
# K=4

# %%
# Data points for h, d, T
x = np.array([1, 2, 3, 4])
h = np.array([6.0247, 3.009, 1.547, 1.0945])
d = np.array([6.1718, 3.0962, 1.5492, 0.7664])
T = np.array([5.807, 2.8584, 1.3577, 0.5687])

# Trend line equations
def trend_h(x):
    return 0.6408 * x**2 - 4.8293 * x + 10.186

def trend_d(x):
    return 0.5732 * x**2 - 4.6423 * x + 10.203

def trend_T(x):
    return 0.5399 * x**2 - 4.4211 * x + 9.6514

# x values for trend lines
x_trend = np.linspace(1, 4, 100)

# Plotting the data points and trend lines
plt.figure(figsize=(5, 3))
plt.plot(x, h, 'o-', color='#F08080', label='h', marker='o', markersize=6)
plt.plot(x, d, 'o-', color='#6495ED', label='d', marker='o', markersize=6)
plt.plot(x, T, 'o-', color='#66CDAA', label='T', marker='o', markersize=6)

# Plotting the trend lines with labels for the legend
plt.plot(x_trend, trend_h(x_trend), '--', color='#FF7F50', label='Trend h')
plt.plot(x_trend, trend_d(x_trend), '--', color='#6495ED', label='Trend d')
plt.plot(x_trend, trend_T(x_trend), '--', color='#3CB371', label='Trend T')

# Setting the axis limits and ticks

plt.xlim(0.9, 4.1)
plt.ylim(0, 6.5)
plt.xticks(x)
plt.tick_params(axis='both', labelsize=16)

# Removing top and right borders
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding a legend
plt.legend(fontsize=11.7)  # 글자 크기를 16으로 설정

# Display and save the plot
#plt.savefig('k4.pdf', format='pdf')  # Save as PDF
plt.savefig('k4.jpg', format='jpg')
plt.show()
# Out:
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\1190501320.py:22: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, h, 'o-', color='#F08080', label='h', marker='o', markersize=6)
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\1190501320.py:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, d, 'o-', color='#6495ED', label='d', marker='o', markersize=6)
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\1190501320.py:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, T, 'o-', color='#66CDAA', label='T', marker='o', markersize=6)

# %% [markdown]
# K=8

# %%
# Data points
x = np.array([1, 2, 3, 4, 5, 6, 7, 8])  # Indexes for the data points
h = np.array([3.7184, 2.7313, 2.3589, 1.3815, 0.8124, 0.3820, 0.1744, 0.7087])
d = np.array([3.7360, 2.8948, 2.4106, 1.3948, 0.7992, 0.3821, 0.1845, 0.1011])
T = np.array([8.2018, 3.4899, 2.5401, 1.7627, 0.9476, 0.5419, 0.3578, 0.2875])

# Trend line equations using logarithmic functions
def trend_h(x):
    return -1.378 * np.log(x) + 3.5742

def trend_d(x):
    return -1.92 * np.log(x) + 4.0338

def trend_T(x):
    return -3.663 * np.log(x) + 7.1379

# x values for the trend lines
x_trend = np.linspace(1, 8, 100)

# Plotting the data points
plt.figure(figsize=(5, 3))
plt.plot(x, h, 'o-', color='#F08080', label='h', marker='o', markersize=6)  # Light Coral color
plt.plot(x, d, 'o-', color='#6495ED', label='d', marker='o', markersize=6)  # Cornflower Blue color
plt.plot(x, T, 'o-', color='#66CDAA', label='T', marker='o', markersize=6)  # Medium Aquamarine color

# 점선을 연한 파스텔 색상으로 조정
plt.plot(x_trend, trend_h(x_trend), '--', color='#FF7F50', label='Trend h')  # Lighter red color
plt.plot(x_trend, trend_d(x_trend), '--', color='#6495ED', label='Trend d')  # Lighter blue color
plt.plot(x_trend, trend_T(x_trend), '--', color='#3CB371', label='Trend T')  # Lighter green color

# Setting the axis limits
plt.xlim(0.8, 8.2)
plt.ylim(0, 8.5)  # Adjust based on your data range
plt.tick_params(axis='both', labelsize=16)

# Removing top and right borders
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding the legend and grid
#plt.savefig('k8.pdf', format='pdf')  # PDF로 저장
plt.savefig('k8.jpg', format='jpg')
plt.grid(False)

# Display the plot
plt.show()
# Out:
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\2613908233.py:22: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, h, 'o-', color='#F08080', label='h', marker='o', markersize=6)  # Light Coral color
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\2613908233.py:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, d, 'o-', color='#6495ED', label='d', marker='o', markersize=6)  # Cornflower Blue color
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\2613908233.py:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
# ...

# %% [markdown]
# K=12

# %%
# Data points for h, d, T
x = np.array(range(1, 13))  # Assuming x values from 1 to 12
h = np.array([1.1299, 6.8735, 4.4682, 2.0329, 1.3388, 0.7357, 0.7149, 0.4261, 0.6461, 0.4154, 0.2179, 0.3444])
d = np.array([-0.2083, 7.0264, 4.6516, 2.1096, 1.374, 0.748, 0.6828, 0.3809, 0.4077, 0.224, 0.1159, 0.0536])
T = np.array([-3.5203, 5.9076, 4.0212, 1.8142, 0.9658, 0.3212, -0.074, -0.4722, -0.7314, -1.2238, -1.3265, -1.4648])

# Trend line equations
def trend_h(x):
    return 0.0289 * x**2 - 0.7486 * x + 4.9117

def trend_d(x):
    return 0.0078 * x**2 - 0.4573 * x + 4.0149

def trend_T(x):
    return -0.0495 * x**2 + 0.3057 * x + 1.0462

# x values for trend lines
x_trend = np.linspace(1, 12, 100)

# Plotting the data points and trend lines
plt.figure(figsize=(5, 3))
plt.plot(x, h, 'o-', color='#F08080', label='h', marker='o', markersize=6)  # Light Coral color
plt.plot(x, d, 'o-', color='#6495ED', label='d', marker='o', markersize=6)  # Cornflower Blue color
plt.plot(x, T, 'o-', color='#66CDAA', label='T', marker='o', markersize=6)  # Medium Aquamarine color

# 점선을 연한 파스텔 색상으로 조정
plt.plot(x_trend, trend_h(x_trend), '--', color='#FF7F50', label='Trend h', linewidth=2)  # Slightly thicker light red line
plt.plot(x_trend, trend_d(x_trend), '--', color='#6495ED', label='Trend d', linewidth=2)  # Slightly thicker light blue line
plt.plot(x_trend, trend_T(x_trend), '--', color='#3CB371', label='Trend T', linewidth=2)  # Slightly thicker light green line

# Setting the axis limits
plt.xticks([4, 8, 12])  # 원하는 x축 위치 지정
plt.ylim(-1.5, 7)  # Adjust based on your data range
plt.tick_params(axis='both', labelsize=16)

# Removing top and right borders
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding the legend and grid
#plt.savefig('k12.pdf', format='pdf')  # PDF로 저장
plt.savefig('k12.jpg', format='jpg')
plt.grid(False)

plt.show()
# Out:
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\3008874909.py:22: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, h, 'o-', color='#F08080', label='h', marker='o', markersize=6)  # Light Coral color
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\3008874909.py:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, d, 'o-', color='#6495ED', label='d', marker='o', markersize=6)  # Cornflower Blue color
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\3008874909.py:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
# ...

# %% [markdown]
# K=16

# %%
# Updated data points for h, d, T
x = np.array(range(1, 17))  # Assuming x values from 1 to 16
h = np.array([0.5602, 0.3329, 1.2282, 1.4916, 1.017, 1.0777, 0.9202, 1.2722, 2.8685, 1.3212, 0.8411, 0.3989, 0.187, 0.0936, 0.0616, 1.1349])
d = np.array([0.3161, 0.2175, -0.2093, 1.6195, 1.084, 1.1121, 0.9249, 1.29, 2.8708, 1.3277, 0.8375, 0.3912, 0.1875, 0.0973, 0.064, 0.0406])
T = np.array([0.0984, -0.0835, -3.513, 0.6933, 0.146, 0.0137, 0.9415, 0.202, 1.2894, -0.256, -0.7142, -1.1954, -1.3832, -1.4649, -1.4901, -1.5134])

# Updated trend line equations using quadratic functions
def trend_h(x):
    return -0.018 * x**2 + 0.2526 * x + 0.3753

def trend_d(x):
    return -0.0284 * x**2 + 0.3955 * x + 0.0063

def trend_T(x):
    return -0.021 * x**2 + 0.1795 * x - 0.0105

# x values for trend lines, making sure it's evenly spaced for better curves
x_trend = np.linspace(1, 16, 100)

# 실선 색상을 더 진하게 조정
plt.figure(figsize=(5, 3))
plt.plot(x, h, 'o-', color='#F08080', label='h', marker='o', markersize=6)  # Light Coral color
plt.plot(x, d, 'o-', color='#6495ED', label='d', marker='o', markersize=6)  # Cornflower Blue color
plt.plot(x, T, 'o-', color='#66CDAA', label='T', marker='o', markersize=6)  # Medium Aquamarine color

# 점선을 연한 파스텔 색상으로 조정
plt.plot(x_trend, trend_h(x_trend), '--', color='#FF7F50', label='Trend h', linewidth=2)  # Slightly thicker light red line
plt.plot(x_trend, trend_d(x_trend), '--', color='#6495ED', label='Trend d', linewidth=2)  # Slightly thicker light blue line
plt.plot(x_trend, trend_T(x_trend), '--', color='#3CB371', label='Trend T', linewidth=2)  # Slightly thicker light green line

# Setting the axis limits
plt.xlim(0.5, 16.5)
plt.ylim(-4, 4)  # Adjust based on your data range

# Setting x-axis ticks
plt.xticks([4, 8, 12, 16])  # 원하는 x축 위치 지정
plt.tick_params(axis='both', labelsize=16)

# Removing top and right borders
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding titles and labels
#plt.legend(fontsize='small', loc='upper right', bbox_to_anchor=(1.25, 1))  # Adjusting legend position outside the plot
#plt.savefig('k16.pdf', format='pdf')  # PDF로 저장
plt.savefig('k16.jpg', format='jpg')
plt.grid(False)

# Display the plot
plt.show()
# Out:
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\2200057997.py:22: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, h, 'o-', color='#F08080', label='h', marker='o', markersize=6)  # Light Coral color
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\2200057997.py:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, d, 'o-', color='#6495ED', label='d', marker='o', markersize=6)  # Cornflower Blue color
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\2200057997.py:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
# ...

# %%
# Updated data points for h, d, T
x = np.array(range(1, 17))  # Assuming x values from 1 to 16
h = np.array([0.5602, 0.3329, 1.2282, 1.4916, 1.017, 1.0777, 0.9202, 1.2722, 2.8685, 1.3212, 0.8411, 0.3989, 0.187, 0.0936, 0.0616, 1.1349])
d = np.array([0.3161, 0.2175, -0.2093, 1.6195, 1.084, 1.1121, 0.9249, 1.29, 2.8708, 1.3277, 0.8375, 0.3912, 0.1875, 0.0973, 0.064, 0.0406])
T = np.array([0.0984, -0.0835, -3.513, 0.6933, 0.146, 0.0137, 0.9415, 0.202, 1.2894, -0.256, -0.7142, -1.1954, -1.3832, -1.4649, -1.4901, -1.5134])

# Updated trend line equations using quadratic functions
def trend_h(x):
    return -0.018 * x**2 + 0.2526 * x + 0.3753

def trend_d(x):
    return -0.0284 * x**2 + 0.3955 * x + 0.0063

def trend_T(x):
    return -0.021 * x**2 + 0.1795 * x - 0.0105

# x values for trend lines, making sure it's evenly spaced for better curves
x_trend = np.linspace(1, 16, 100)

# Plotting the data points
plt.figure(figsize=(5, 3))
plt.plot(x, h, 'o-', color='#FF7F50', label='Final h', marker='o', markersize=3)  # Slightly darker Tomato color
plt.plot(x, d, 'o-', color='#87CEFA', label='Final d', marker='o', markersize=3)  # Slightly darker Steel blue
plt.plot(x, T, 'o-', color='#98FB98', label='Final T', marker='o', markersize=3)  # Slightly darker Lime green

# Plotting the trend lines
plt.plot(x_trend, trend_h(x_trend), '--', color='#FF4500', label='Trend h')  # Darker red color
plt.plot(x_trend, trend_d(x_trend), '--', color='#4169E1', label='Trend d')  # Darker blue color
plt.plot(x_trend, trend_T(x_trend), '--', color='#2E8B57', label='Trend T')  # Darker green color

# Setting the axis limits
plt.xlim(0, 17)
plt.ylim(-4, 4)

# Setting x-axis ticks
plt.xticks(x)

# Adding titles and labels
plt.legend(fontsize='small', loc='upper right', bbox_to_anchor=(1.25, 1))  # Adjusting legend position outside the plot

plt.grid(False)

# Display the plot
plt.show()
# Out:
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\1702199464.py:22: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, h, 'o-', color='#FF7F50', label='Final h', marker='o', markersize=3)  # Slightly darker Tomato color
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\1702199464.py:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, d, 'o-', color='#87CEFA', label='Final d', marker='o', markersize=3)  # Slightly darker Steel blue
# C:\Users\Dayena Jeong\AppData\Local\Temp\ipykernel_20504\1702199464.py:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
# ...

# %%
loss_values_20000 = [4.537033557891846, 1.0502341985702515, 0.38060617446899414, 0.19721515476703644, 0.1384907215833664, 0.11013998091220856, 0.0856538861989975, 0.0718691349029541, 0.06244693696498871, 0.0543963685631752, 0.04754360392689705, 0.04207532852888107, 0.03809645399451256, 0.03547537699341774, 0.03294850513339043, 0.03038366138935089, 0.02862509712576866, 0.027360966429114342, 0.02544204518198967, 0.023521579802036285, 0.02162361890077591, 0.020199060440063477, 0.018883319571614265, 0.017590735107660294, 0.01635904051363468, 0.015216469764709473, 0.013939283788204193, 0.012662810273468494, 0.011778686195611954, 0.010936571285128593, 0.010092692449688911, 0.009338542819023132, 0.008701466955244541, 0.007848626002669334, 0.0070284330286085606, 0.0065420689061284065, 0.006110530812293291, 0.005674739368259907, 0.004940296057611704, 0.00447092903777957, 0.004144223406910896, 0.0037082782946527004, 0.0033933159429579973, 0.003077293047681451, 0.0028443539049476385, 0.002587393391877413
017140459967777133, 0.0015683923847973347, 0.0015471044462174177, 0.0015486663905903697, 0.001490768394432962, 0.0014002660755068064, 0.001214685500599444, 0.0010826849611476064, 0.001031152787618339, 0.0009860324207693338, 0.0009197897161357105, 0.0008914359495975077, 0.000879216764587909, 0.0009047315106727183, 0.0009786341106519103, 0.0009791208431124687, 0.0010885241208598018, 0.0011279734317213297, 0.0011345064267516136, 0.0011106700403615832, 0.0012460718862712383, 0.0012806332670152187, 0.0012482433812692761, 0.0012188046239316463, 0.0011901241960003972, 0.0012002793373540044, 0.0012706501875072718, 0.0013711114879697561, 0.0014386865077540278, 0.001506495987996459, 0.0015489739598706365, 0.002011903328821063, 0.0017003481043502688, 0.001651134924031794, 0.0016091284342110157, 0.0015063714236021042, 0.0014113957295194268, 0.0013620010577142239, 0.0012956741265952587, 0.0012220172211527824, 0.0011446685530245304, 0.0010789623484015465, 0.0010216636583209038, 0.000981063349172473, 0.0009429448982700706, 0.0009039681171998382, 0.0008883478003554046, 0.0008678063750267029, 0.0008278932073153555, 0.0007906437967903912, 0.0007550992304459214, 0.0007098874775692821, 0.0006714436458423734, 0.0006536221480928361, 0.0006492671091109514, 0.0006337311933748424, 0.0006165406666696072, 0.0006097117438912392, 0.0006112356786616147, 0.0005981158465147018, 0.0005864761769771576, 0.0005823153187520802, 0.0005762260407209396, 0.0005708479438908398, 0.000565931259188801, 0.0005695095169357955, 0.0005697637097910047, 0.0005770539282821119, 0.0005721488851122558, 0.0005635498091578484, 0.0005583572201430798, 0.0005474264617078006, 0.0005480675026774406, 0.0005370730068534613, 0.0005390492151491344, 0.0005368120037019253, 0.00053107098210603, 0.0005374242318794131, 0.0005339167546480894, 0.0005303859943524003]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

plt.figure(figsize=(4, 3))

# 0부터 20000 에폭까지의 데이터 플롯
x_range_20000 = np.linspace(0, 20000, 100)
plt.plot(x_range_20000, loss_values_20000, label='Loss 0-20K epochs', color='blue')

# 20000부터 40000 에폭까지의 데이터 플롯
x_range_20000_40000 = np.linspace(20000, 40000, 100)
plt.plot(x_range_20000_40000, loss_values_plus_20000, label='Loss 20-40K epochs', color='green')
plt.plot(x_range_20000_40000, loss_values_plus_gaussian, label='Gaussian Noise Loss', color='#FF8C00')
plt.plot(x_range_20000_40000, loss_values_plus_modify, label='Ours loss', color='red')

# 축 레이블 및 범례 설정
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1))
plt.xlim(7000, 40000)
plt.ylim(-0.00001, 0.004)
plt.grid(False)

# x축에 20000과 40000에 세로 점선 추가
plt.axvline(x=20000, color='black', linestyle='--', linewidth=0.5)

# x축 눈금 레이블을 'K' 단위로 포맷팅
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{int(x/1000)}K'))

# y축 눈금 레이블을 소수점 두 자리로 포맷팅
plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2e'))
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(5))  # y축 눈금 최대 개수를 5개로 제한

# Removing top and right borders
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# 축 눈금 레이블 크기 조정
plt.tick_params(axis='both', which='major', labelsize=10)  # 글자 크기를 더 키움

# Display and save the plot
plt.savefig('loss.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)

plt.show()
